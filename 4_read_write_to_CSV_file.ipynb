# %% [markdown]
# # Read/Write CSV and Excel Files in Pandas

# %% [markdown]
# ***Read CSV***

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\Vinsc\\OneDrive\\Documents\\4_pandas_new.csv")

df
# Out:
#   Stock data     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0    tickers            eps    Revenue      price         people
# 1      GOOGL          27.82         87        845     larry page
# 2        WMT           4.61        484         65           n.a.
# 3       MSFT             -1         85         64     bill gates
# 4        RIL  not available         50       1023  mukesh ambani
# 5       TATA            5.6         -1       n.a.     ratan tata

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\Vinsc\\OneDrive\\Documents\\4_pandas_new.csv" , skiprows = 1)

df
# Out:
#   tickers            eps  Revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3     RIL  not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\Vinsc\\OneDrive\\Documents\\4_pandas_new.csv" , header = 1)

df
# Out:
#   tickers            eps  Revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3     RIL  not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\Vinsc\\OneDrive\\Documents\\4_pandas_new.csv" , skiprows = 2 , header = None)

df
# Out:
#        0              1    2     3              4
# 0  GOOGL          27.82   87   845     larry page
# 1    WMT           4.61  484    65           n.a.
# 2   MSFT             -1   85    64     bill gates
# 3    RIL  not available   50  1023  mukesh ambani
# 4   TATA            5.6   -1  n.a.     ratan tata

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\Vinsc\\OneDrive\\Documents\\4_pandas_new.csv" , skiprows = 2,header = None , names = ["Ticker" , "eps" , 'Revenue' , 'Price' , 'People'])

df
# Out:
#   Ticker            eps  Revenue Price         People
# 0  GOOGL          27.82       87   845     larry page
# 1    WMT           4.61      484    65           n.a.
# 2   MSFT             -1       85    64     bill gates
# 3    RIL  not available       50  1023  mukesh ambani
# 4   TATA            5.6       -1  n.a.     ratan tata

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\Vinsc\\OneDrive\\Documents\\4_pandas_new.csv" , skiprows = 1 , nrows = 5) 

df
# Out:
#   tickers            eps  Revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3     RIL  not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\Vinsc\\OneDrive\\Documents\\4_pandas_new.csv" , skiprows = 1 , na_values = ["not available" , "n.a."]) 

df
# Out:
#   tickers    eps  Revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3     RIL    NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\Vinsc\\OneDrive\\Documents\\4_pandas_new.csv" , skiprows = 1 , 
                 na_values = {
                     'eps' : ['not available' , 'n.a.'],
                     'Revenue': ['not available' , 'n.a.' , -1],
                     'people': ['not available' , 'n.a.']
                 }) 

df
# Out:
#   tickers    eps  Revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3     RIL    NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %%
df.to_csv('new.csv' , index = False )

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'Revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv("news.csv" , columns=['tickers' , 'price'])

# %%
df.to_csv("latest.csv" , header = False)
